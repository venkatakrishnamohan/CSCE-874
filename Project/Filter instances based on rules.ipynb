# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('compressed_association_final_instances copy.csv')

# %%
data.head()
# Out:
#    Unnamed: 0    TRU    count  day   event_id       lat      lon  month  \
# 0           0  Urban     more    2  258094576  11.06670  76.0667      7
# 1           1  Urban  average   16  259662992  12.50000  75.0000      7
# 2           2  Rural     less   16  259679155   9.85000  76.9667      7
# 3           3  Urban  average   19  268327050   8.88056  76.5917      9
# 4           4  Rural     more   19  287435840  10.00000  76.5000      2
#
#   protest category  state_2  year Social Status (A/NA)      pop infra_area  \
# 0           Appeal   Kerala  2013                 poor     less       good
# 1           Appeal   Kerala  2013               better     more       good
# 2          Assault   Kerala  2013                 poor     more     better
# 3          Assault   Kerala  2013               better  average     better
# 4           Appeal   Kerala  2014               better     more     better
#
#   social_housing    distance infra_num  infra_dist
# ...

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
rule_instances = pd.read_csv('rules_protest1_pca.csv',sep=' ')
#rule_instances.drop(['Unnamed: 0'],inplace=True,axis=1)
ans = data.merge(rule_instances,left_on = 'event_id',right_on='l1',how='right')
ans.to_csv('rules_protest1_pca_df.csv')

# %%
rule_instances = pd.read_csv('../test3.csv',sep=' ')

# %%
ans.shape
# Out:
# (436, 18)

# %%
rule_instances.shape
# Out:
# (3951, 1)

# %%
data.merge(rule_instances,left_on = 'event_id',right_on='X[[i]]',how='right')
# Out:
#        TRU count  day   event_id       lat      lon  month protest category  \
# 0    Rural  less   18  272137762   9.49417  76.3275     10            Fight
# 1    Rural  less    2  481040870   9.49417  76.3275     11            Fight
# 2    Rural  less   21  411144570   9.49417  76.3275      2            Fight
# 3    Rural  less   10  258996029   9.49417  76.3275      7            Fight
# 4    Rural  less   30  303220469   9.49417  76.3275      6            Fight
# 5    Rural  less   14  323480364   9.49417  76.3275     11            Fight
# 6    Rural  less   27  264778058   9.49417  76.3275      8            Fight
# 7    Rural  less   23  451500584   9.49417  76.3275      7            Fight
# 8    Rural  less   19  418370530   9.49417  76.3275      3            Fight
# 9    Rural  less    7  537913211   9.49417  76.3275      5            Fight
# 10   Rural  less   27  701650718   9.49417  76.3275     10            Fight
# ...
