# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/Users/venkatakrishnamohansunkara/Desktop/Data Mining/project/pop_data'

# %%
import glob

# %%
all_data2 = pd.DataFrame()

# %%
for f in glob.glob("tot_pop_data/*.csv"):
    df = pd.read_csv(f)
    all_data2 = all_data2.append(df,ignore_index=True)

# %%
all_data2
# Out:
#         Unnamed: 0  State  District  Subdistt  Town/Village  Ward  \
# 0                0     29       564         0             0     0
# 1                1     29       564         0             0     0
# 2                2     29       564         0             0     0
# 3                3     29       564      5489             0     0
# 4                4     29       564      5489             0     0
# 5                5     29       564      5489             0     0
# 6                6     29       564      5489        603879     0
# 7                7     29       564      5489        603880     0
# 8                8     29       564      5489        603881     0
# 9                9     29       564      5489        603882     0
# 10              10     29       564      5489        603883     0
# 11              11     29       564      5489        603884     0
# 12              12     29       564      5489        603885     0
# ...

# %%
reqd_list = ['State', 'District', 'Subdistt', 'Town/Village', 'Ward', 'Level',
       'Name', 'TRU', 'No_HH', 'TOT_P', 'TOT_M', 'TOT_F', 'P_SC', 'P_ST',  'P_LIT',
       'M_LIT', 'F_LIT', 'P_ILL', 'M_ILL', 'F_ILL', 'TOT_WORK_P', 'TOT_WORK_M',
       'TOT_WORK_F', 'MAINWORK_P', 'MAIN_CL_P',
        'MAIN_AL_P', 
       'MAIN_HH_P', 'MARGWORK_P', 'MARGWORK_M', 'MARGWORK_F', 'MARG_CL_P',
        'MARG_AL_P',
       'MARG_HH_P',  'NON_WORK_P',
       'NON_WORK_M', 'NON_WORK_F']

# %%
final_data= all_data2[reqd_list]

# %%
final_data.to_csv('total_pop_data.csv')
